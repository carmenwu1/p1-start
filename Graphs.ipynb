# %%
# !python --version
# Out:
# Python 3.5.2 :: Anaconda 4.2.0 (64-bit)

# %%
# Importing the good stuff
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
# loading text files
# filename = sys.argv[1]
glass = np.loadtxt("raw-data/Sp15_245L_sect-001_group-1_glass.raw", delimiter=",",skiprows=32 )

# %%
# plotting stress vs strain
plt.plot(glass[1],glass[3],"k-", linestyle='dashed')
# plt.title
plt.xlabel("Strain")
plt.ylabel('Stress (MPa)')
plt.grid(True)
# plt.legend(loc="best")
plt.show()
